# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your interests.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

# learning_rates = [1e-9, 1e-8, 1e-7]
# regularization_strengths = [5e4, 5e5, 5e6]
learning_rates = [6e-7]*2
regularization_strengths = [1000]*2

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
for lr in learning_rates:
    for reg in regularization_strengths:
        classifier = LinearSVM()
        stats = classifier.train(X_train_feats, y_train,
                             learning_rate=lr, reg=reg,
                             num_iters=10000, batch_size=300,
                             verbose=False)
        train_acc = np.mean(classifier.predict(X_train_feats) == y_train)
        val_acc = np.mean(classifier.predict(X_val_feats) == y_val)
        results[(lr, reg)] = train_acc, val_acc
        print(f"lr = {lr:e}, reg = {reg:e} => train accuracy = {train_acc}, val accuracy = {val_acc}")
        if best_val < val_acc:
            best_val = val_acc
            from copy import deepcopy
            best_svm = deepcopy(classifier)
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    #print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
    #            lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# lr = 6.000000e-07, reg = 1.000000e+03 => train accuracy = 0.415265306122449, val accuracy = 0.421
# lr = 6.000000e-07, reg = 1.000000e+03 => train accuracy = 0.4161020408163265, val accuracy = 0.417
# lr = 6.000000e-07, reg = 1.000000e+03 => train accuracy = 0.41651020408163264, val accuracy = 0.422
# lr = 6.000000e-07, reg = 1.000000e+03 => train accuracy = 0.41622448979591836, val accuracy = 0.419
# best validation accuracy achieved during cross-validation: 0.422000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.42

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
# Not really. However I do notice that the svm classifier isn't looking much at the background color. Especially most of the pictures whose ground truth label is 'ship' has blue backgrounds, but from the classifications, other pictures with blue backgrounds were not classfied as ships.

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 155)
# (49000, 154)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
best_val_acc = -1
best_lr, best_reg, best_stat = -1, -1, None

for _ in range(200):
    net = TwoLayerNet(input_dim, hidden_dim, num_classes)

    lr, reg = np.random.uniform(0.5, 1), np.random.uniform(0.5, 5)*1e-3
    print(f'#{i}: learning rate = {lr:e}, regularization strength = {reg:e}')
    
    stat = net.train(X_train_feats, y_train, X_val_feats, y_val,
                    learning_rate=lr, learning_rate_decay=0.9,
                    reg=reg, num_iters=1500, 
                    batch_size=200, verbose=False)
    
    train_acc = (net.predict(X_train_feats) == y_train).mean()
    val_acc = (net.predict(X_val_feats) == y_val).mean()
    
    if best_val_acc < val_acc:
        best_val_acc = val_acc
        import copy
        best_net = copy.deepcopy(net)
        best_lr = lr
        best_reg = reg
        best_stat = stat
    
    print(f'Training accuracy: {train_acc:.3}, Validation accuracy: {val_acc:.3}')
    print()

print('Achieved validation accuracy {val_acc:.3} with learning rate {lr:e} and reg {reg:.3}')
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# learning rate = 6.911402e-01, regularization strength = 2.940864e-03
# Training accuracy: 0.604, Validation accuracy: 0.554
#
# learning rate = 9.795522e-01, regularization strength = 3.128328e-03
# Training accuracy: 0.605, Validation accuracy: 0.579
#
# learning rate = 8.898824e-01, regularization strength = 4.417712e-03
# Training accuracy: 0.578, Validation accuracy: 0.555
#
# learning rate = 9.330494e-01, regularization strength = 4.738299e-03
# Training accuracy: 0.573, Validation accuracy: 0.547
#
# learning rate = 7.301782e-01, regularization strength = 3.104873e-03
# Training accuracy: 0.607, Validation accuracy: 0.575
#
# learning rate = 8.876402e-01, regularization strength = 1.551335e-03
# Training accuracy: 0.652, Validation accuracy: 0.564
#
# learning rate = 5.173510e-01, regularization strength = 4.503377e-03
# Training accuracy: 0.576, Validation accuracy: 0.561
#
# learning rate = 8.700191e-01, regularization strength = 3.222033e-03
# Training accuracy: 0.595, Validation accuracy: 0.538
#
# learning rate = 7.613240e-01, regularization strength = 3.872318e-03
# Training accuracy: 0.588, Validation accuracy: 0.551
#
# learning rate = 6.496703e-01, regularization strength = 4.141185e-03
# Training accuracy: 0.584, Validation accuracy: 0.552
#
# learning rate = 7.155069e-01, regularization strength = 1.712299e-03
# Training accuracy: 0.642, Validation accuracy: 0.564
#
# learning rate = 7.046216e-01, regularization strength = 1.362701e-03
# Training accuracy: 0.655, Validation accuracy: 0.581
#
# learning rate = 5.358308e-01, regularization strength = 1.515094e-03
# Training accuracy: 0.634, Validation accuracy: 0.585
#
# learning rate = 5.430177e-01, regularization strength = 1.266680e-03
# Training accuracy: 0.645, Validation accuracy: 0.593
#
# learning rate = 9.220279e-01, regularization strength = 2.240850e-03
# Training accuracy: 0.623, Validation accuracy: 0.581
#
# learning rate = 9.002788e-01, regularization strength = 2.720522e-03
# Training accuracy: 0.611, Validation accuracy: 0.556
#
# learning rate = 6.112502e-01, regularization strength = 3.848065e-03
# Training accuracy: 0.581, Validation accuracy: 0.557
#
# learning rate = 6.670505e-01, regularization strength = 2.050709e-03
# Training accuracy: 0.629, Validation accuracy: 0.589
#
# learning rate = 6.696960e-01, regularization strength = 1.642461e-03
# Training accuracy: 0.641, Validation accuracy: 0.581
#
# learning rate = 9.085471e-01, regularization strength = 3.110353e-03
# Training accuracy: 0.598, Validation accuracy: 0.556
#
# learning rate = 6.671762e-01, regularization strength = 2.914094e-03
# Training accuracy: 0.609, Validation accuracy: 0.589
#
# learning rate = 8.266275e-01, regularization strength = 3.319408e-03
# Training accuracy: 0.597, Validation accuracy: 0.551
#
# learning rate = 7.932313e-01, regularization strength = 4.141474e-03
# Training accuracy: 0.584, Validation accuracy: 0.554
#
# learning rate = 8.886163e-01, regularization strength = 1.083126e-03
# Training accuracy: 0.667, Validation accuracy: 0.586
#
# learning rate = 6.371378e-01, regularization strength = 2.597532e-03
# Training accuracy: 0.613, Validation accuracy: 0.579
#
# learning rate = 5.410387e-01, regularization strength = 1.522989e-03
# Training accuracy: 0.639, Validation accuracy: 0.58
#
# learning rate = 7.551623e-01, regularization strength = 4.771211e-03
# Training accuracy: 0.579, Validation accuracy: 0.563
#
# learning rate = 7.457321e-01, regularization strength = 3.318019e-03
# Training accuracy: 0.601, Validation accuracy: 0.566
#
# learning rate = 8.137233e-01, regularization strength = 4.327927e-03
# Training accuracy: 0.576, Validation accuracy: 0.535
#
# learning rate = 7.022774e-01, regularization strength = 1.581618e-03
# Training accuracy: 0.647, Validation accuracy: 0.592
#
# learning rate = 6.863945e-01, regularization strength = 3.643089e-03
# Training accuracy: 0.588, Validation accuracy: 0.557
#
# learning rate = 7.953388e-01, regularization strength = 3.198574e-03
# Training accuracy: 0.6, Validation accuracy: 0.571
#
# learning rate = 6.692027e-01, regularization strength = 4.603094e-03
# Training accuracy: 0.564, Validation accuracy: 0.544
#
# learning rate = 8.529676e-01, regularization strength = 1.588445e-03
# Training accuracy: 0.65, Validation accuracy: 0.586
#
# learning rate = 5.222576e-01, regularization strength = 4.406158e-03
# Training accuracy: 0.574, Validation accuracy: 0.554
#
# learning rate = 8.062800e-01, regularization strength = 4.370431e-03
# Training accuracy: 0.578, Validation accuracy: 0.556
#
# learning rate = 9.736491e-01, regularization strength = 2.583996e-03
# Training accuracy: 0.614, Validation accuracy: 0.578
#
# learning rate = 8.866208e-01, regularization strength = 2.510917e-03
# Training accuracy: 0.62, Validation accuracy: 0.574
#
# learning rate = 5.221146e-01, regularization strength = 3.782183e-03
# Training accuracy: 0.589, Validation accuracy: 0.562
#
# learning rate = 5.428882e-01, regularization strength = 2.170772e-03
# Training accuracy: 0.625, Validation accuracy: 0.583
#
# learning rate = 5.058889e-01, regularization strength = 4.757955e-03
# Training accuracy: 0.567, Validation accuracy: 0.544
#
# learning rate = 5.467910e-01, regularization strength = 2.767415e-03
# Training accuracy: 0.609, Validation accuracy: 0.578
#
# learning rate = 9.355920e-01, regularization strength = 1.848081e-03
# Training accuracy: 0.634, Validation accuracy: 0.56
#
# learning rate = 5.231136e-01, regularization strength = 2.960085e-03
# Training accuracy: 0.601, Validation accuracy: 0.565
#
# learning rate = 7.401362e-01, regularization strength = 3.069570e-03
# Training accuracy: 0.604, Validation accuracy: 0.56
#
# learning rate = 7.862746e-01, regularization strength = 1.311913e-03
# Training accuracy: 0.649, Validation accuracy: 0.582
#
# learning rate = 6.261776e-01, regularization strength = 3.129171e-03
# Training accuracy: 0.599, Validation accuracy: 0.572
#
# learning rate = 6.428421e-01, regularization strength = 2.763411e-03
# Training accuracy: 0.608, Validation accuracy: 0.559
#
# learning rate = 9.995715e-01, regularization strength = 4.057309e-03
# Training accuracy: 0.581, Validation accuracy: 0.572
#
# learning rate = 7.645130e-01, regularization strength = 3.360760e-03
# Training accuracy: 0.594, Validation accuracy: 0.561
#
# learning rate = 8.788969e-01, regularization strength = 1.899394e-03
# Training accuracy: 0.637, Validation accuracy: 0.57
#
# learning rate = 8.494547e-01, regularization strength = 1.243323e-03
# Training accuracy: 0.666, Validation accuracy: 0.579
#
# learning rate = 9.522972e-01, regularization strength = 2.032989e-03
# Training accuracy: 0.636, Validation accuracy: 0.576
#
# learning rate = 7.707112e-01, regularization strength = 1.302973e-03
# Training accuracy: 0.661, Validation accuracy: 0.593
#
# learning rate = 9.498389e-01, regularization strength = 1.294343e-03
# Training accuracy: 0.664, Validation accuracy: 0.591
#
# learning rate = 9.997443e-01, regularization strength = 1.474203e-03
# Training accuracy: 0.652, Validation accuracy: 0.559
#
# learning rate = 7.021361e-01, regularization strength = 1.587828e-03
# Training accuracy: 0.642, Validation accuracy: 0.574
#
# learning rate = 8.900310e-01, regularization strength = 4.611028e-03
# Training accuracy: 0.569, Validation accuracy: 0.557
#
# learning rate = 7.484297e-01, regularization strength = 2.026405e-03
# Training accuracy: 0.63, Validation accuracy: 0.583
#
# learning rate = 7.409161e-01, regularization strength = 1.400647e-03
# Training accuracy: 0.651, Validation accuracy: 0.601
#
# learning rate = 7.623178e-01, regularization strength = 4.224520e-03
# Training accuracy: 0.575, Validation accuracy: 0.539
#
# learning rate = 5.091190e-01, regularization strength = 1.488871e-03
# Training accuracy: 0.631, Validation accuracy: 0.575
#
# learning rate = 7.768683e-01, regularization strength = 3.978930e-03
# Training accuracy: 0.588, Validation accuracy: 0.586
#
# learning rate = 9.632642e-01, regularization strength = 1.601414e-03
# Training accuracy: 0.649, Validation accuracy: 0.585
#
# learning rate = 9.019498e-01, regularization strength = 1.551634e-03
# Training accuracy: 0.652, Validation accuracy: 0.585
#
# learning rate = 7.423889e-01, regularization strength = 3.956323e-03
# Training accuracy: 0.589, Validation accuracy: 0.552
#
# learning rate = 8.148982e-01, regularization strength = 4.540619e-03
# Training accuracy: 0.571, Validation accuracy: 0.555
#
# learning rate = 8.472579e-01, regularization strength = 2.307697e-03
# Training accuracy: 0.628, Validation accuracy: 0.576
#
# learning rate = 5.848936e-01, regularization strength = 2.357104e-03
# Training accuracy: 0.619, Validation accuracy: 0.578
#
# learning rate = 9.551549e-01, regularization strength = 3.499657e-03
# Training accuracy: 0.591, Validation accuracy: 0.564
#
# learning rate = 9.788006e-01, regularization strength = 4.238999e-03
# Training accuracy: 0.578, Validation accuracy: 0.542
#
# learning rate = 5.943864e-01, regularization strength = 4.811333e-03
# Training accuracy: 0.568, Validation accuracy: 0.549
#
# learning rate = 9.288685e-01, regularization strength = 2.866921e-03
# Training accuracy: 0.604, Validation accuracy: 0.573
#
# learning rate = 9.668180e-01, regularization strength = 2.434256e-03
# Training accuracy: 0.619, Validation accuracy: 0.583
#
# learning rate = 9.238138e-01, regularization strength = 1.108263e-03
# Training accuracy: 0.671, Validation accuracy: 0.572
#
# learning rate = 7.158662e-01, regularization strength = 2.320055e-03
# Training accuracy: 0.619, Validation accuracy: 0.558
#
# learning rate = 7.440249e-01, regularization strength = 1.352362e-03
# Training accuracy: 0.656, Validation accuracy: 0.585
#
# learning rate = 8.913018e-01, regularization strength = 2.371318e-03
# Training accuracy: 0.623, Validation accuracy: 0.578
#
# learning rate = 7.825049e-01, regularization strength = 1.245719e-03
# Training accuracy: 0.66, Validation accuracy: 0.584
#
# learning rate = 6.864654e-01, regularization strength = 2.769457e-03
# Training accuracy: 0.612, Validation accuracy: 0.57
#
# learning rate = 7.794529e-01, regularization strength = 2.214652e-03
# Training accuracy: 0.624, Validation accuracy: 0.58
#
# learning rate = 9.130710e-01, regularization strength = 1.658255e-03
# Training accuracy: 0.651, Validation accuracy: 0.599
#
# learning rate = 9.823925e-01, regularization strength = 4.710260e-03
# Training accuracy: 0.573, Validation accuracy: 0.552
#
# learning rate = 5.432525e-01, regularization strength = 4.530188e-03
# Training accuracy: 0.568, Validation accuracy: 0.52
#
# learning rate = 9.413495e-01, regularization strength = 1.414352e-03
# Training accuracy: 0.66, Validation accuracy: 0.59
#
# learning rate = 7.679109e-01, regularization strength = 1.938792e-03
# Training accuracy: 0.63, Validation accuracy: 0.573
#
# learning rate = 5.354047e-01, regularization strength = 2.241463e-03
# Training accuracy: 0.613, Validation accuracy: 0.566
#
# learning rate = 7.206610e-01, regularization strength = 3.063250e-03
# Training accuracy: 0.603, Validation accuracy: 0.565
#
# learning rate = 5.970835e-01, regularization strength = 4.556174e-03
# Training accuracy: 0.575, Validation accuracy: 0.554
#
# learning rate = 9.007054e-01, regularization strength = 1.319189e-03
# Training accuracy: 0.663, Validation accuracy: 0.598
#
# learning rate = 6.888432e-01, regularization strength = 3.901160e-03
# Training accuracy: 0.587, Validation accuracy: 0.556
#
# learning rate = 8.245764e-01, regularization strength = 1.628293e-03
# Training accuracy: 0.643, Validation accuracy: 0.589
#
# learning rate = 7.119765e-01, regularization strength = 2.925576e-03
# Training accuracy: 0.608, Validation accuracy: 0.586
#
# learning rate = 6.434769e-01, regularization strength = 2.756245e-03
# Training accuracy: 0.606, Validation accuracy: 0.577
#
# learning rate = 5.669619e-01, regularization strength = 1.474254e-03
# Training accuracy: 0.639, Validation accuracy: 0.567
#
# learning rate = 6.887499e-01, regularization strength = 4.160949e-03
# Training accuracy: 0.583, Validation accuracy: 0.558
#
# learning rate = 7.469500e-01, regularization strength = 2.774268e-03
# Training accuracy: 0.613, Validation accuracy: 0.585
#
# learning rate = 5.035722e-01, regularization strength = 3.963177e-03
# Training accuracy: 0.58, Validation accuracy: 0.561
#
# learning rate = 8.368302e-01, regularization strength = 4.850609e-03
# Training accuracy: 0.572, Validation accuracy: 0.56
#
# learning rate = 8.806129e-01, regularization strength = 4.697988e-03
# Training accuracy: 0.572, Validation accuracy: 0.572
#
# learning rate = 8.150439e-01, regularization strength = 2.130780e-03
# Training accuracy: 0.626, Validation accuracy: 0.593
#
# learning rate = 5.569165e-01, regularization strength = 1.451430e-03
# Training accuracy: 0.639, Validation accuracy: 0.58
#
# learning rate = 5.136317e-01, regularization strength = 4.511994e-03
# Training accuracy: 0.577, Validation accuracy: 0.558
#
# learning rate = 6.799823e-01, regularization strength = 1.794564e-03
# Training accuracy: 0.642, Validation accuracy: 0.584
#
# learning rate = 6.766973e-01, regularization strength = 3.630860e-03
# Training accuracy: 0.595, Validation accuracy: 0.565
#
# learning rate = 5.347129e-01, regularization strength = 3.012921e-03
# Training accuracy: 0.595, Validation accuracy: 0.559
#
# learning rate = 7.803232e-01, regularization strength = 3.278727e-03
# Training accuracy: 0.597, Validation accuracy: 0.556
#
# learning rate = 5.901861e-01, regularization strength = 1.641574e-03
# Training accuracy: 0.637, Validation accuracy: 0.583
#
# learning rate = 9.767623e-01, regularization strength = 2.374633e-03
# Training accuracy: 0.605, Validation accuracy: 0.546
#
# learning rate = 5.794108e-01, regularization strength = 1.239390e-03
# Training accuracy: 0.649, Validation accuracy: 0.573
#
# learning rate = 7.198229e-01, regularization strength = 1.187351e-03
# Training accuracy: 0.66, Validation accuracy: 0.592
#
# learning rate = 8.448526e-01, regularization strength = 3.643704e-03
# Training accuracy: 0.583, Validation accuracy: 0.538
#
# learning rate = 6.369793e-01, regularization strength = 3.121448e-03
# Training accuracy: 0.602, Validation accuracy: 0.562
#
# learning rate = 6.688772e-01, regularization strength = 2.704816e-03
# Training accuracy: 0.612, Validation accuracy: 0.571
#
# learning rate = 8.472764e-01, regularization strength = 1.286522e-03
# Training accuracy: 0.662, Validation accuracy: 0.591
#
# learning rate = 6.955296e-01, regularization strength = 4.032986e-03
# Training accuracy: 0.589, Validation accuracy: 0.57
#
# learning rate = 5.177257e-01, regularization strength = 2.534769e-03
# Training accuracy: 0.608, Validation accuracy: 0.564
#
# learning rate = 5.345374e-01, regularization strength = 3.148777e-03
# Training accuracy: 0.6, Validation accuracy: 0.572
#
# learning rate = 8.271373e-01, regularization strength = 3.934905e-03
# Training accuracy: 0.581, Validation accuracy: 0.562
#
# learning rate = 5.028019e-01, regularization strength = 2.003476e-03
# Training accuracy: 0.622, Validation accuracy: 0.576
#
# learning rate = 7.573948e-01, regularization strength = 1.061621e-03
# Training accuracy: 0.668, Validation accuracy: 0.6
#
# learning rate = 9.867518e-01, regularization strength = 1.743405e-03
# Training accuracy: 0.644, Validation accuracy: 0.582
#
# learning rate = 6.296290e-01, regularization strength = 4.486273e-03
# Training accuracy: 0.575, Validation accuracy: 0.554
#
# learning rate = 8.296502e-01, regularization strength = 1.763991e-03
# Training accuracy: 0.646, Validation accuracy: 0.591
#
# learning rate = 8.656716e-01, regularization strength = 3.175576e-03
# Training accuracy: 0.6, Validation accuracy: 0.547
#
# learning rate = 7.026991e-01, regularization strength = 1.825559e-03
# Training accuracy: 0.635, Validation accuracy: 0.596
#
# learning rate = 8.659363e-01, regularization strength = 1.916185e-03
# Training accuracy: 0.64, Validation accuracy: 0.573
#
# learning rate = 5.962665e-01, regularization strength = 4.860383e-03
# Training accuracy: 0.568, Validation accuracy: 0.556
#
# learning rate = 6.885187e-01, regularization strength = 4.671828e-03
# Training accuracy: 0.575, Validation accuracy: 0.55
#
# learning rate = 5.166757e-01, regularization strength = 2.120686e-03
# Training accuracy: 0.623, Validation accuracy: 0.586
#
# learning rate = 8.059279e-01, regularization strength = 1.361017e-03
# Training accuracy: 0.658, Validation accuracy: 0.588
#
# learning rate = 9.725678e-01, regularization strength = 2.628811e-03
# Training accuracy: 0.608, Validation accuracy: 0.57
#
# learning rate = 9.269479e-01, regularization strength = 3.834437e-03
# Training accuracy: 0.584, Validation accuracy: 0.537
#
# learning rate = 8.236732e-01, regularization strength = 4.774694e-03
# Training accuracy: 0.568, Validation accuracy: 0.539
#
# learning rate = 7.872540e-01, regularization strength = 1.288934e-03
# Training accuracy: 0.659, Validation accuracy: 0.594
#
# learning rate = 9.806226e-01, regularization strength = 4.869338e-03
# Training accuracy: 0.568, Validation accuracy: 0.541
#
# learning rate = 9.148511e-01, regularization strength = 4.253965e-03
# Training accuracy: 0.577, Validation accuracy: 0.555
#
# learning rate = 8.599797e-01, regularization strength = 1.345059e-03
# Training accuracy: 0.66, Validation accuracy: 0.575
#
# learning rate = 8.987417e-01, regularization strength = 2.482344e-03
# Training accuracy: 0.616, Validation accuracy: 0.562
#
# learning rate = 6.260126e-01, regularization strength = 1.303190e-03
# Training accuracy: 0.655, Validation accuracy: 0.582
#
# learning rate = 5.334278e-01, regularization strength = 4.453534e-03
# Training accuracy: 0.577, Validation accuracy: 0.548
#
# learning rate = 7.738027e-01, regularization strength = 2.581405e-03
# Training accuracy: 0.62, Validation accuracy: 0.572
#
# learning rate = 5.644295e-01, regularization strength = 3.223386e-03
# Training accuracy: 0.596, Validation accuracy: 0.562
#
# learning rate = 5.658177e-01, regularization strength = 1.122983e-03
# Training accuracy: 0.654, Validation accuracy: 0.587
#
# learning rate = 6.758895e-01, regularization strength = 4.473997e-03
# Training accuracy: 0.575, Validation accuracy: 0.544
#
# learning rate = 9.868364e-01, regularization strength = 1.566895e-03
# Training accuracy: 0.652, Validation accuracy: 0.576
#
# learning rate = 9.977317e-01, regularization strength = 3.222747e-03
# Training accuracy: 0.596, Validation accuracy: 0.562
#
# learning rate = 9.202693e-01, regularization strength = 2.634868e-03
# Training accuracy: 0.608, Validation accuracy: 0.569
#
# learning rate = 9.414800e-01, regularization strength = 4.246188e-03
# Training accuracy: 0.57, Validation accuracy: 0.537
#
# learning rate = 5.044126e-01, regularization strength = 2.036265e-03
# Training accuracy: 0.624, Validation accuracy: 0.589
#
# learning rate = 5.027569e-01, regularization strength = 3.999014e-03
# Training accuracy: 0.581, Validation accuracy: 0.56
#
# learning rate = 7.337314e-01, regularization strength = 3.027101e-03
# Training accuracy: 0.609, Validation accuracy: 0.563
#
# learning rate = 7.317782e-01, regularization strength = 2.610576e-03
# Training accuracy: 0.614, Validation accuracy: 0.581
#
# learning rate = 5.688776e-01, regularization strength = 4.471453e-03
# Training accuracy: 0.577, Validation accuracy: 0.538
#
# learning rate = 9.746590e-01, regularization strength = 2.211933e-03
# Training accuracy: 0.628, Validation accuracy: 0.588
#
# learning rate = 6.507715e-01, regularization strength = 1.080913e-03
# Training accuracy: 0.661, Validation accuracy: 0.599
#
# learning rate = 7.553523e-01, regularization strength = 4.333218e-03
# Training accuracy: 0.572, Validation accuracy: 0.536
#
# learning rate = 5.162210e-01, regularization strength = 2.453858e-03
# Training accuracy: 0.609, Validation accuracy: 0.576
#
# learning rate = 5.135406e-01, regularization strength = 2.460075e-03
# Training accuracy: 0.61, Validation accuracy: 0.578
#
# learning rate = 7.721575e-01, regularization strength = 4.143519e-03
# Training accuracy: 0.582, Validation accuracy: 0.556
#
# learning rate = 6.283719e-01, regularization strength = 3.713097e-03
# Training accuracy: 0.583, Validation accuracy: 0.554
#
# learning rate = 9.497314e-01, regularization strength = 1.280695e-03
# Training accuracy: 0.662, Validation accuracy: 0.566
#
# learning rate = 6.104448e-01, regularization strength = 4.547638e-03
# Training accuracy: 0.574, Validation accuracy: 0.558
#
# learning rate = 9.487432e-01, regularization strength = 2.232950e-03
# Training accuracy: 0.628, Validation accuracy: 0.577
#
# learning rate = 6.912603e-01, regularization strength = 3.764909e-03
# Training accuracy: 0.59, Validation accuracy: 0.56
#
# learning rate = 5.237189e-01, regularization strength = 3.390611e-03
# Training accuracy: 0.595, Validation accuracy: 0.569
#
# learning rate = 5.377698e-01, regularization strength = 3.030961e-03
# Training accuracy: 0.596, Validation accuracy: 0.544
#
# learning rate = 8.977449e-01, regularization strength = 2.321319e-03
# Training accuracy: 0.625, Validation accuracy: 0.587
#
# learning rate = 7.723940e-01, regularization strength = 1.224308e-03
# Training accuracy: 0.665, Validation accuracy: 0.594
#
# learning rate = 5.616017e-01, regularization strength = 1.599651e-03
# Training accuracy: 0.636, Validation accuracy: 0.568
#
# learning rate = 7.249927e-01, regularization strength = 3.858343e-03
# Training accuracy: 0.578, Validation accuracy: 0.545
#
# learning rate = 7.882862e-01, regularization strength = 1.073681e-03
# Training accuracy: 0.665, Validation accuracy: 0.587
#
# learning rate = 6.735275e-01, regularization strength = 1.333266e-03
# Training accuracy: 0.651, Validation accuracy: 0.567
#
# learning rate = 6.936745e-01, regularization strength = 1.520122e-03
# Training accuracy: 0.644, Validation accuracy: 0.576
#
# learning rate = 7.213409e-01, regularization strength = 3.319320e-03
# Training accuracy: 0.596, Validation accuracy: 0.56
#
# learning rate = 5.554466e-01, regularization strength = 4.800363e-03
# Training accuracy: 0.568, Validation accuracy: 0.541
#
# learning rate = 7.472362e-01, regularization strength = 4.354684e-03
# Training accuracy: 0.58, Validation accuracy: 0.562
#
# learning rate = 6.395595e-01, regularization strength = 2.961174e-03
# Training accuracy: 0.607, Validation accuracy: 0.583
#
# learning rate = 9.476095e-01, regularization strength = 3.458555e-03
# Training accuracy: 0.592, Validation accuracy: 0.556
#
# learning rate = 5.826229e-01, regularization strength = 2.638393e-03
# Training accuracy: 0.609, Validation accuracy: 0.586
#
# learning rate = 6.123615e-01, regularization strength = 2.698163e-03
# Training accuracy: 0.615, Validation accuracy: 0.579
#
# learning rate = 8.130702e-01, regularization strength = 3.665591e-03
# Training accuracy: 0.59, Validation accuracy: 0.568
#
# learning rate = 6.175581e-01, regularization strength = 4.102454e-03
# Training accuracy: 0.58, Validation accuracy: 0.529
#
# learning rate = 8.315582e-01, regularization strength = 3.018231e-03
# Training accuracy: 0.608, Validation accuracy: 0.583
#
# learning rate = 9.894150e-01, regularization strength = 2.979242e-03
# Training accuracy: 0.598, Validation accuracy: 0.573
#
# learning rate = 7.100447e-01, regularization strength = 3.764374e-03
# Training accuracy: 0.587, Validation accuracy: 0.541
#
# learning rate = 8.007503e-01, regularization strength = 1.773466e-03
# Training accuracy: 0.64, Validation accuracy: 0.578
#
# learning rate = 9.489124e-01, regularization strength = 1.805917e-03
# Training accuracy: 0.64, Validation accuracy: 0.583
#
# learning rate = 8.233242e-01, regularization strength = 2.479959e-03
# Training accuracy: 0.621, Validation accuracy: 0.581
#
# learning rate = 6.268313e-01, regularization strength = 1.117070e-03
# Training accuracy: 0.655, Validation accuracy: 0.606
#
# learning rate = 9.604318e-01, regularization strength = 3.016699e-03
# Training accuracy: 0.602, Validation accuracy: 0.59
#
# learning rate = 7.310693e-01, regularization strength = 1.747588e-03
# Training accuracy: 0.639, Validation accuracy: 0.59
#
# learning rate = 9.910100e-01, regularization strength = 2.222713e-03
# Training accuracy: 0.632, Validation accuracy: 0.591
#
# learning rate = 5.262561e-01, regularization strength = 4.922742e-03
# Training accuracy: 0.569, Validation accuracy: 0.557
#
# learning rate = 5.246970e-01, regularization strength = 3.119801e-03
# Training accuracy: 0.595, Validation accuracy: 0.565
#
# learning rate = 9.137039e-01, regularization strength = 3.915813e-03
# Training accuracy: 0.577, Validation accuracy: 0.542
#
# learning rate = 5.742711e-01, regularization strength = 1.255464e-03
# Training accuracy: 0.651, Validation accuracy: 0.584
#
# learning rate = 9.550766e-01, regularization strength = 1.401928e-03
# Training accuracy: 0.661, Validation accuracy: 0.581
#
# learning rate = 7.353902e-01, regularization strength = 4.230405e-03
# Training accuracy: 0.582, Validation accuracy: 0.542
#
# learning rate = 8.151449e-01, regularization strength = 1.895647e-03
# Training accuracy: 0.626, Validation accuracy: 0.575
#
# 0.6268313422665244 0.0011170697051774844 0.606

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.

test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.573
